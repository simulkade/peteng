# %% [markdown]
# # An old FiPy solution to 1D BL
# I'm not really sure if the result is correct.
# The results is indeed incorrect. See the updated code a few cells below that might work slightly better.

# %%
# import packages and define the functions
import relative_permeability as relperm
import fractional_flow as ff
from fipy import *
import numpy as np
import matplotlib.pyplot as plt

# %%
# define parameters
u = 1.e-3
L = 100.
nx = 200
dx = L/nx
muo = 0.002
muw = 0.001
p0 = 100e5
k=1e-12
phi=0.3

swc = 0.1
sor = 0.15
krw0 = 0.3
kro0 = 1.0
nw = 2.0
no = 2.0

kro = lambda sw: relperm.kro(sw, kro0, sor, swc, no)
krw = lambda sw: relperm.krw(sw, krw0, sor, swc, nw)
dkrw = lambda sw: relperm.dkrwdsw(sw, krw0, sor, swc, nw)
dkro = lambda sw: relperm.dkrodsw(sw, kro0, sor, swc, no)

# %%
# plot the rel-perms
sw_plot = np.linspace(0, 1, 50)
krw_plot = [krw(sw) for sw in sw_plot]
kro_plot = [kro(sw) for sw in sw_plot]

plt.figure(1)
plt.plot(sw_plot, krw_plot, sw_plot, kro_plot)
# Out:
# [<matplotlib.lines.Line2D at 0x7fdda741f940>,
#  <matplotlib.lines.Line2D at 0x7fdda741f9a0>]

# %%
# define the mesh and variables
mesh = Grid1D(dx = L/nx, nx = nx)
x = mesh.cellCenters

# create the cell variables and boundary conditions
sw = CellVariable(mesh=mesh, name="saturation", hasOld=True, value = swc)
p = CellVariable(mesh=mesh, name="pressure", hasOld=True, value = p0)

# %%
# Boundary conditions
sw.constrain(1.0, mesh.facesLeft)
#sw.constrain(0., mesh.facesRight)
sw.faceGrad.constrain([0], mesh.facesRight)
p.constrain(p0, mesh.facesRight)
# p.constrain(1.1*p0, mesh.facesLeft)
p.faceGrad.constrain([-u/(krw(1-sor)*k/muw)], mesh.facesLeft)

# %%
# define the equations
eq_p = DiffusionTerm(var=p, coeff=-k*(krw(sw.faceValue)/muw+kro(sw.faceValue)/muo))- \
UpwindConvectionTerm(var=sw, coeff=-k*(dkrw(sw.faceValue)/muw+dkro(sw.faceValue)/muo)*p.faceGrad)- \
(k*(dkrw(sw.faceValue)/muw+dkro(sw.faceValue)/muo)*sw.faceValue*p.faceGrad).divergence == 0

eq_sw = TransientTerm(coeff=phi, var=sw) + \
DiffusionTerm(var=p, coeff=-k*krw(sw.faceValue)/muw)+ \
UpwindConvectionTerm(var=sw, coeff=-k*dkrw(sw.faceValue)/muw*p.faceGrad)- \
(-k*dkrw(sw.faceValue)/muw*p.faceGrad*sw.faceValue).divergence == 0

# %%
steps = 20
dt = 2000.
viewer = Viewer(vars = sw, datamax=1.1, datamin=-0.1)
for step in range(steps):
    sw.updateOld()
    swres = 1.0e6
    while swres > 1e-5:
        pres=eq_p.sweep(dt = dt, var = p)
        swres=eq_sw.sweep(dt = dt, var = sw)
        print(f'error is pressure {pres:.5f} and saturation {swres:.5f}')
        p.updateOld()
        sw.updateOld()
# viewer.plot()
# Out:
# error is pressure 0.00333 and saturation 0.00333
# error is pressure 0.00471 and saturation 0.00471
# error is pressure 0.00471 and saturation 0.00471
# error is pressure 0.00527 and saturation 0.00667
# error is pressure 0.00527 and saturation 0.00667
# error is pressure 0.00707 and saturation 0.00816
# error is pressure 0.00707 and saturation 0.00816
# error is pressure 0.00745 and saturation 0.00943
# error is pressure 0.00745 and saturation 0.00943
# error is pressure 0.00882 and saturation 0.01054
# error is pressure 0.00882 and saturation 0.01030
# error is pressure 0.00913 and saturation 0.01155
# error is pressure 0.00913 and saturation 0.01155
# error is pressure 0.01027 and saturation 0.01247
# error is pressure 0.01027 and saturation 0.01247
# error is pressure 0.01054 and saturation 0.01315
# error is pressure 0.01054 and saturation 0.01333
# error is pressure 0.01155 and saturation 0.01414
# error is pressure 0.01155 and saturation 0.01398
# error is pressure 0.01155 and saturation 0.01478
# error is pressure 0.56003 and saturation 0.01480
# error is pressure 1.11275 and saturation 0.01563
# error is pressure 0.01269 and saturation 0.01559
# error is pressure 0.01291 and saturation 0.01633
# error is pressure 0.01291 and saturation 0.01619
# error is pressure 0.01374 and saturation 0.01700
# error is pressure 0.01374 and saturation 0.01692
# error is pressure 0.01394 and saturation 0.01764
# error is pressure 0.56005 and saturation 0.01764
# error is pressure 1.11279 and saturation 0.01992
# error is pressure 0.02288 and saturation 0.01893
# error is pressure 0.02085 and saturation 0.01886
# error is pressure 0.56010 and saturation 0.01875
# error is pressure 1.11278 and saturation 0.01944
# error is pressure 0.01563 and saturation 0.01922
# error is pressure 0.01581 and saturation 0.02000
# error is pressure 0.56010 and saturation 0.02000
# error is pressure 1.11280 and saturation 0.02055
# error is pressure 0.01633 and saturation 0.02048
# error is pressure 0.01789 and saturation 0.02095
# error is pressure 0.56013 and saturation 0.02108
# error is pressure 1.11281 and saturation 0.02129
# error is pressure 0.01768 and saturation 0.02147
# error is pressure 0.02197 and saturation 0.02250
# error is pressure 0.56025 and saturation 0.02211
# error is pressure 1.11283 and saturation 0.02257
# error is pressure 0.01769 and saturation 0.02252
# error is pressure 0.01828 and saturation 0.02293
# error is pressure 0.01826 and saturation 0.02309
# error is pressure 0.01886 and saturation 0.02357
# error is pressure 0.01939 and saturation 0.02424
# error is pressure 0.02702 and saturation 0.02404
# error is pressure 0.56028 and saturation 0.02404
# error is pressure 1.11285 and saturation 0.02449
# error is pressure 0.01931 and saturation 0.02449
# error is pressure 0.01972 and saturation 0.02494
# error is pressure 0.01972 and saturation 0.02461
# error is pressure 0.02028 and saturation 0.02539
# error is pressure 0.02028 and saturation 0.02533
# error is pressure 0.02041 and saturation 0.02582
# error is pressure 0.56025 and saturation 0.02569
# error is pressure 1.11288 and saturation 0.02625
# error is pressure 0.02095 and saturation 0.02625
# error is pressure 0.02108 and saturation 0.02667
# error is pressure 0.02165 and saturation 0.02615
# error is pressure 0.03688 and saturation 0.12895
# error is pressure 0.03582 and saturation 0.02717
# error is pressure 0.02674 and saturation 0.02748
# error is pressure 0.56153 and saturation 0.15315
# error is pressure 1.11410 and saturation 0.02761
# error is pressure 0.02530 and saturation 0.02826
# error is pressure 0.02469 and saturation 0.02826
# error is pressure 0.56036 and saturation 0.02820
# error is pressure 1.11291 and saturation 0.02851
# error is pressure 0.02285 and saturation 0.02860
# error is pressure 0.02297 and saturation 0.02906
# error is pressure 0.56035 and saturation 0.02906
# error is pressure 1.11293 and saturation 0.02944
# error is pressure 0.02345 and saturation 0.02944
# error is pressure 0.02357 and saturation 0.02981
# error is pressure 0.56037 and saturation 0.02981
# error is pressure 1.11294 and saturation 0.03018
# error is pressure 0.02579 and saturation 0.03486
# error is pressure 0.04478 and saturation 0.03261
# error is pressure 0.04131 and saturation 0.03059
# error is pressure 0.02913 and saturation 0.03079
# error is pressure 0.02367 and saturation 0.03084
# error is pressure 0.02472 and saturation 0.03114
# error is pressure 0.56042 and saturation 0.03127
# error is pressure 1.11296 and saturation 0.03162
# error is pressure 0.02517 and saturation 0.03162
# error is pressure 0.02528 and saturation 0.03197
# error is pressure 0.56045 and saturation 0.03197
# error is pressure 1.11298 and saturation 0.03232
# error is pressure 0.02571 and saturation 0.03232
# error is pressure 0.02582 and saturation 0.03266
# error is pressure 0.56047 and saturation 0.03266
# error is pressure 1.11299 and saturation 0.03300
# error is pressure 0.02625 and saturation 0.03300
# error is pressure 0.02635 and saturation 0.03333
# error is pressure 0.56050 and saturation 0.03333
# error is pressure 1.11300 and saturation 0.03367
# error is pressure 0.02677 and saturation 0.03367
# error is pressure 0.02687 and saturation 0.03399
# error is pressure 0.56052 and saturation 0.03399
# error is pressure 1.11301 and saturation 0.03432
# error is pressure 0.02728 and saturation 0.03432
# error is pressure 0.02739 and saturation 0.03464
# error is pressure 0.56055 and saturation 0.03464
# error is pressure 1.11303 and saturation 0.03496
# error is pressure 0.02779 and saturation 0.03496
# error is pressure 0.02789 and saturation 0.03528
# error is pressure 0.56057 and saturation 0.03528
# error is pressure 1.11304 and saturation 0.03559
# error is pressure 0.02828 and saturation 0.03559
# error is pressure 0.02838 and saturation 0.03573
# error is pressure 0.56060 and saturation 0.03590
# error is pressure 1.11305 and saturation 0.03621
# error is pressure 0.02877 and saturation 0.03621
# error is pressure 0.02887 and saturation 0.03651
# error is pressure 0.02887 and saturation 0.03639
# error is pressure 0.02925 and saturation 0.03682
# error is pressure 0.02925 and saturation 0.03682
# error is pressure 0.02934 and saturation 0.03698
# error is pressure 0.02953 and saturation 0.03693
# error is pressure 0.03039 and saturation 0.03732
# error is pressure 0.02972 and saturation 0.03742
# error is pressure 0.02981 and saturation 0.03771
# error is pressure 0.02981 and saturation 0.03771
# error is pressure 0.03156 and saturation 0.04117
# error is pressure 0.04847 and saturation 0.03898
# error is pressure 0.04024 and saturation 0.03831
# error is pressure 0.56073 and saturation 0.03820
# error is pressure 1.11308 and saturation 0.03852
# error is pressure 0.03064 and saturation 0.03823
# error is pressure 0.03073 and saturation 0.03885
# error is pressure 0.56072 and saturation 0.03887
# error is pressure 1.11311 and saturation 0.03916
# error is pressure 0.03109 and saturation 0.03903
# error is pressure 0.03118 and saturation 0.03944
# error is pressure 0.03118 and saturation 0.03944
# error is pressure 0.03153 and saturation 0.03939
# error is pressure 0.03217 and saturation 0.03993
# error is pressure 0.04592 and saturation 0.23224
# error is pressure 0.05129 and saturation 0.04005
# error is pressure 0.03516 and saturation 0.04140
# error is pressure 0.03710 and saturation 0.04108
# error is pressure 0.03766 and saturation 0.04045
# error is pressure 0.56085 and saturation 0.04224
# error is pressure 1.11325 and saturation 0.04073
# error is pressure 0.03375 and saturation 0.04067
# error is pressure 0.03298 and saturation 0.04110
# error is pressure 0.03285 and saturation 0.04107
# error is pressure 0.03283 and saturation 0.04131
# error is pressure 0.03291 and saturation 0.04125
# error is pressure 0.03320 and saturation 0.04159
# error is pressure 0.03291 and saturation 0.04163
# error is pressure 0.03333 and saturation 0.04161
# error is pressure 0.03357 and saturation 0.04184
# error is pressure 0.03337 and saturation 0.04195
# error is pressure 0.03333 and saturation 0.04216
# error is pressure 0.03371 and saturation 0.04236
# error is pressure 0.03389 and saturation 0.04223
# error is pressure 0.05318 and saturation 0.12065
# error is pressure 0.05208 and saturation 0.04248
# error is pressure 0.03615 and saturation 0.04319
# error is pressure 0.03564 and saturation 0.04283
# error is pressure 0.03444 and saturation 0.04312
# error is pressure 0.04965 and saturation 0.12408
# error is pressure 0.03938 and saturation 0.04354
# error is pressure 0.03907 and saturation 0.04340
# error is pressure 0.03653 and saturation 0.04668
# error is pressure 0.05219 and saturation 0.04464
# error is pressure 0.04835 and saturation 0.04343
# error is pressure 0.03951 and saturation 0.04351
# error is pressure 0.04077 and saturation 0.05118
# error is pressure 0.04341 and saturation 0.04360
# error is pressure 0.03970 and saturation 0.04539
# error is pressure 0.05078 and saturation 0.04403
# error is pressure 0.04145 and saturation 0.04371
# error is pressure 0.56102 and saturation 0.04368
# error is pressure 1.11324 and saturation 0.04581
# error is pressure 0.04526 and saturation 0.04414
# error is pressure 0.04344 and saturation 0.04374
# error is pressure 0.56116 and saturation 0.04363
# error is pressure 1.11322 and saturation 0.04431
# error is pressure 0.03674 and saturation 0.04378
# error is pressure 0.04262 and saturation 0.10110
# error is pressure 0.03855 and saturation 0.04388
# error is pressure 0.03846 and saturation 0.04394
# error is pressure 0.03539 and saturation 0.04390
# error is pressure 0.03477 and saturation 0.04388
# error is pressure 0.56095 and saturation 0.04369
# error is pressure 1.11323 and saturation 0.04394
# error is pressure 0.03489 and saturation 0.04389
# error is pressure 0.03496 and saturation 0.04398
# error is pressure 0.03545 and saturation 0.04535
# error is pressure 0.04476 and saturation 0.04463
# error is pressure 0.04048 and saturation 0.04398
# error is pressure 0.03547 and saturation 0.04420
# error is pressure 0.03464 and saturation 0.04402
# error is pressure 0.03512 and saturation 0.04430
# error is pressure 0.03529 and saturation 0.04512
# error is pressure 0.04062 and saturation 0.04466
# error is pressure 0.03955 and saturation 0.04423
# error is pressure 0.03737 and saturation 0.04622
# error is pressure 0.04331 and saturation 0.04461
# error is pressure 0.03899 and saturation 0.04435
# error is pressure 0.56102 and saturation 0.04409
# error is pressure 1.11324 and saturation 0.04438
# error is pressure 0.03512 and saturation 0.04435
# error is pressure 0.03544 and saturation 0.04510
# error is pressure 0.04208 and saturation 0.04444
# error is pressure 0.03805 and saturation 0.04436
# error is pressure 0.03596 and saturation 0.04441
# error is pressure 0.03501 and saturation 0.04450
# error is pressure 0.03500 and saturation 0.04424
# error is pressure 0.03528 and saturation 0.04447
# error is pressure 0.03528 and saturation 0.04433
# error is pressure 0.03536 and saturation 0.04472
# error is pressure 0.56098 and saturation 0.04460
# error is pressure 1.11324 and saturation 0.04450
# error is pressure 0.05164 and saturation 0.13962
# error is pressure 0.05786 and saturation 0.04465
# error is pressure 0.03735 and saturation 0.04497
# error is pressure 0.03700 and saturation 0.04483
# error is pressure 0.03538 and saturation 0.04451
# error is pressure 0.04405 and saturation 0.09759
# error is pressure 0.03740 and saturation 0.04506
# error is pressure 0.03999 and saturation 0.04599
# error is pressure 0.04286 and saturation 0.04501
# error is pressure 0.04105 and saturation 0.04606
# error is pressure 0.04439 and saturation 0.04525
# error is pressure 0.04171 and saturation 0.04494
# error is pressure 0.03837 and saturation 0.04488
# error is pressure 0.03571 and saturation 0.04543
# error is pressure 0.56113 and saturation 0.04521
# error is pressure 1.11336 and saturation 0.04511
# error is pressure 0.03721 and saturation 0.04497
# error is pressure 0.03686 and saturation 0.04656
# error is pressure 0.04588 and saturation 0.04560
# error is pressure 0.04144 and saturation 0.04493
# error is pressure 0.03818 and saturation 0.04490
# error is pressure 0.03575 and saturation 0.04522
# error is pressure 0.56101 and saturation 0.04509
# error is pressure 1.11325 and saturation 0.04509
# error is pressure 0.03616 and saturation 0.04629
# error is pressure 0.04300 and saturation 0.04579
# error is pressure 0.56143 and saturation 0.04518
# error is pressure 1.11334 and saturation 0.04630
# error is pressure 0.04119 and saturation 0.04552
# error is pressure 0.04035 and saturation 0.04523
# error is pressure 0.03778 and saturation 0.04517
# error is pressure 0.03645 and saturation 0.04636
# error is pressure 0.04437 and saturation 0.04546
# error is pressure 0.04004 and saturation 0.04523
# error is pressure 0.03759 and saturation 0.04508
# error is pressure 0.03606 and saturation 0.04546
# error is pressure 0.03590 and saturation 0.04522
# error is pressure 0.03578 and saturation 0.04530
# error is pressure 0.03575 and saturation 0.04522
# error is pressure 0.03606 and saturation 0.04546
# error is pressure 0.03606 and saturation 0.04546
# error is pressure 0.03682 and saturation 0.04785
# error is pressure 0.04775 and saturation 0.04633
# error is pressure 0.04603 and saturation 0.04548
# error is pressure 0.04062 and saturation 0.04529
# error is pressure 0.03613 and saturation 0.04570
# error is pressure 0.56103 and saturation 0.04556
# error is pressure 1.11326 and saturation 0.04558
# error is pressure 0.03606 and saturation 0.04546
# error is pressure 0.03613 and saturation 0.04570
# error is pressure 0.03598 and saturation 0.04556
# error is pressure 0.03694 and saturation 0.04786
# error is pressure 0.04800 and saturation 0.04645
# error is pressure 0.04608 and saturation 0.04572
# error is pressure 0.04077 and saturation 0.04559
# error is pressure 0.03658 and saturation 0.04570
# error is pressure 0.03609 and saturation 0.04558
# error is pressure 0.03637 and saturation 0.04637
# error is pressure 0.03999 and saturation 0.04631
# error is pressure 0.04112 and saturation 0.04598
# error is pressure 0.03899 and saturation 0.04556
# error is pressure 0.03682 and saturation 0.04569
# error is pressure 0.03613 and saturation 0.04570
# error is pressure 0.03714 and saturation 0.04812
# error is pressure 0.04822 and saturation 0.04656
# error is pressure 0.04606 and saturation 0.04574
# error is pressure 0.04066 and saturation 0.04559
# error is pressure 0.03644 and saturation 0.04595
# error is pressure 0.03629 and saturation 0.04583
# error is pressure 0.03617 and saturation 0.04583
# error is pressure 0.03613 and saturation 0.04570
# error is pressure 0.03644 and saturation 0.04591
# error is pressure 0.03629 and saturation 0.04583
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [77], in <cell line: 4>()
#       6 swres = 1.0e6
#       7 while swres > 1e-5:
# ----> 8     pres=eq_p.sweep(dt = dt, var = p)
#       9     swres=eq_sw.sweep(dt = dt, var = sw)
#      10     print(f'error is pressure {pres:.5f} and saturation {swres:.5f}')
#
# File ~/miniconda3/envs/myfipy/lib/python3.10/site-packages/fipy/terms/term.py:216, in Term.sweep(self, var, solver, boundaryConditions, dt, underRelaxation, residualFn, cacheResidual, cacheError)
#     214 solver = self._prepareLinearSystem(var=var, solver=solver, boundaryConditions=boundaryConditions, dt=dt)
#     215 solver._applyUnderRelaxation(underRelaxation=underRelaxation)
# --> 216 residual = solver._calcResidual(residualFn=residualFn)
#     218 if cacheResidual or cacheError:
#     219     self.residualVector = solver._calcResidualVector(residualFn=residualFn)
#
# File ~/miniconda3/envs/myfipy/lib/python3.10/site-packages/fipy/solvers/petsc/petscSolver.py:91, in PETScSolver._calcResidual(self, residualFn)
#      89 else:
#      90     comm = self.var.mesh.communicator
# ---> 91     residual, globalMatrix = self._calcResidualVector_()
#      92     return comm.Norm2(residual)
#
# File ~/miniconda3/envs/myfipy/lib/python3.10/site-packages/fipy/solvers/petsc/petscSolver.py:82, in PETScSolver._calcResidualVector_(self)
#      81 def _calcResidualVector_(self):
# ---> 82     globalMatrix, overlappingVector, overlappingRHSvector = self._globalMatrixAndVectors
#      83     residual = globalMatrix * overlappingVector - overlappingRHSvector
#      84     return residual, globalMatrix
#
# File ~/miniconda3/envs/myfipy/lib/python3.10/site-packages/fipy/solvers/petsc/petscSolver.py:31, in PETScSolver._globalMatrixAndVectors(self)
#      29     RHSvector = self.RHSvector
#      30 else:
# ---> 31     RHSvector = numerix.reshape(numerix.asarray(self.RHSvector), self.var.shape)
#      33 overlappingRHSvector = self.matrix._fipy2petscGhost(var=RHSvector)
#      35 self.globalVectors = (globalMatrix, overlappingVector, overlappingRHSvector)
#
# File ~/miniconda3/envs/myfipy/lib/python3.10/site-packages/fipy/tools/numerix.py:162, in reshape(arr, shape)
#     156 def reshape(arr, shape):
#     157     """
#     158     Change the shape of `arr` to `shape`, as long as the product of all the
#     159     lengths of all the axes is constant (the total number of elements does not
#     160     change).
#     161     """
# --> 162     if -1 in shape:
#     163         # e.g., NUMERIX.reshape(a, (-1, N)) fails if N == 0
#     164         oldShape = array(getShape(arr))
#     165         oldShape[oldShape == 0] = 1
#
# KeyboardInterrupt:

# %% [markdown]
# ## Equations
# $$\varphi \frac{\partial S_w}{\partial t}+u \frac{\partial f_w}{\partial x}=0$$ or
# $$\varphi \frac{\partial S_w}{\partial t}+\nabla.\left( u \frac{\partial f_w}{\partial S_w} S_w\right)+ \nabla. \left( u f_w-u\frac{\partial f_w}{\partial S_w} S_{w0} \right)=0$$

# %% [markdown]
# ## Analytical solution

# %%
xt_shock, sw_shock, xt_prf, sw_prf, t, p_inj, R_oil = ff.frac_flow_wf(muw=muw, muo=muo, ut=u, phi=1.0, \
  k=1e-12, swc=swc, sor=sor, kro0=kro0, no=no, krw0=krw0, \
  nw=nw, sw0=swc, sw_inj=1.0, L=L, pv_inj=5.0)

# %%
plt.figure()
plt.plot(xt_prf, sw_prf)
plt.plot(x.value.squeeze()/(steps*dt), sw.value)
plt.show()
